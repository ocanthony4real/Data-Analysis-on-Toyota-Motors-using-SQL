# %%
import pandas as pd
import yfinance as yf
from sqlalchemy import create_engine

# %%
TM = yf.Ticker("TM")

# %%
financials = TM.financials
financials
# Out:
#                                               2022-03-31        2021-03-31  \
# Research Development                                None              None
# Effect Of Accounting Charges                        None              None
# Income Before Tax                        3990532000000.0   2932355000000.0
# Minority Interest                         908851000000.0    883782000000.0
# Net Income                               2850110000000.0   2245261000000.0
# Selling General Administrative           2975977000000.0   2634625000000.0
# Gross Profit                             5971673000000.0   4832373000000.0
# Ebit                                     2995696000000.0   2197748000000.0
# Operating Income                         2995696000000.0   2197748000000.0
# Other Operating Expenses                            None              None
# Interest Expense                          -32458000000.0    -42421000000.0
# ...

# %%
financials = financials.transpose()
financials
# Out:
#            Research Development Effect Of Accounting Charges  \
#
# 2022-03-31                 None                         None
# 2021-03-31                 None                         None
# 2020-03-31                 None                         None
# 2019-03-31                 None                         None
#
#            Income Before Tax Minority Interest       Net Income  \
#
# 2022-03-31   3990532000000.0    908851000000.0  2850110000000.0
# 2021-03-31   2932355000000.0    883782000000.0  2245261000000.0
# 2020-03-31   2792942000000.0    720124000000.0  2036140000000.0
# 2019-03-31   2645531000000.0    718985000000.0  1882873000000.0
#
#            Selling General Administrative     Gross Profit             Ebit  \
#
# 2022-03-31                2975977000000.0  5971673000000.0  2995696000000.0
# 2021-03-31                2634625000000.0  4832373000000.0  2197748000000.0
# 2020-03-31                2981965000000.0  5381196000000.0  2399231000000.0
# ...

# %%
financials.columns = financials.columns.str.replace(' ', '_')
financials.index.names = ['Date']
financials.head(2)
# Out:
#            Research_Development Effect_Of_Accounting_Charges  \
# Date
# 2022-03-31                 None                         None
# 2021-03-31                 None                         None
#
#            Income_Before_Tax Minority_Interest       Net_Income  \
# Date
# 2022-03-31   3990532000000.0    908851000000.0  2850110000000.0
# 2021-03-31   2932355000000.0    883782000000.0  2245261000000.0
#
#            Selling_General_Administrative     Gross_Profit             Ebit  \
# Date
# 2022-03-31                2975977000000.0  5971673000000.0  2995696000000.0
# 2021-03-31                2634625000000.0  4832373000000.0  2197748000000.0
#
#            Operating_Income Other_Operating_Expenses  ... Non_Recurring  \
# Date                                                  ...
# 2022-03-31  2995696000000.0                     None  ...          None
# 2021-03-31  2197748000000.0                     None  ...          None
#
# ...

# %%
engine = create_engine("mysql+pymysql://root:8669627426@localhost/toyotamotors")
financials.to_sql("financials", con = engine)

# %%
balance_sheet = TM.balance_sheet
balance_sheet
# Out:
#                                                 2022-03-31    2021-03-31  \
# Intangible Assets                             5.282040e+11  4.774580e+11
# Capital Surplus                               4.985750e+11  4.972750e+11
# Total Liab                                    4.053395e+13  3.797881e+13
# Total Stockholder Equity                      2.624597e+13  2.340455e+13
# Minority Interest                             9.088510e+11  8.837820e+11
# Deferred Long Term Liab                       6.637620e+11  6.311760e+11
# Other Current Liab                            5.746939e+12  4.719716e+12
# Total Assets                                  6.768877e+13  6.226714e+13
# Common Stock                                  3.970500e+11  3.970500e+11
# Other Current Assets                          3.229570e+12  4.922674e+12
# Retained Earnings                             2.645313e+13  2.410418e+13
# Other Liab                                    3.038904e+12  2.824396e+12
# ...
